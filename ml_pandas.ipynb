# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51105/batch-06_2403A51105_AI_assignments/blob/main/ml_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/student_performance.csv')

# %%
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.shape
# Out:
# (1000000, 6)

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
df.dtypes
# Out:
# student_id                   int64
# weekly_self_study_hours    float64
# attendance_percentage      float64
# class_participation        float64
# total_score                float64
# grade                       object
# dtype: object

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.tail()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 999995                  4.8        100.0     A
# 999996                  6.7         88.3     A
# 999997                  5.8         87.9     A
# 999998                  5.3        100.0     A
# 999999                  4.1        100.0     A

# %%
df.describe()
# Out:
#            student_id  weekly_self_study_hours  attendance_percentage  \
# count  1000000.000000           1000000.000000         1000000.000000
# mean    500000.500000                15.029127              84.711046
# std     288675.278933                 6.899431               9.424143
# min          1.000000                 0.000000              50.000000
# 25%     250000.750000                10.300000              78.300000
# 50%     500000.500000                15.000000              85.000000
# 75%     750000.250000                19.700000              91.800000
# max    1000000.000000                40.000000             100.000000
#
#        class_participation     total_score
# count       1000000.000000  1000000.000000
# mean              5.985203       84.283845
# std               1.956421       15.432969
# min               0.000000        9.400000
# 25%               4.700000       73.900000
# 50%               6.000000       87.500000
# ...

# %%
df.student_id
# Out:
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
#            ...
# 999995     999996
# 999996     999997
# 999997     999998
# 999998     999999
# 999999    1000000
# Name: student_id, Length: 1000000, dtype: int64

# %%
score=['total_score', 'grade']
df[score]
# Out:
#         total_score grade
# 0              97.9     A
# 1              83.9     B
# 2             100.0     A
# 3             100.0     A
# 4              92.0     A
# ...             ...   ...
# 999995        100.0     A
# 999996         88.3     A
# 999997         87.9     A
# 999998        100.0     A
# 999999        100.0     A
#
# [1000000 rows x 2 columns]

# %%
df[df['total_score']>70]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df[df['grade']=='A']
# df[df['grade']=='B']
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# 5                6                     13.4                   65.1
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 2                       5.3        100.0     A
# ...

# %%
df['grade'].value_counts()
# Out:
# grade
# A    548644
# B    258174
# C    141980
# D     44998
# F      6204
# Name: count, dtype: int64
